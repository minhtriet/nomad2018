# %%
import torch
import torch_geometric
import numpy as np
from torch_geometric.data import Data

# %%
import networkx as nx

# %%
CONVERTED_TO_PYG_DATA = 0

# %% [markdown]
# ### Read target

# %%
import pandas as pd

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('train.csv')

# %%
min(train_df.bandgap_energy_ev)
# Out:
# 0.0001

# %%
train_df.head()
# Out:
#    id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0   1          33                   80.0           0.6250           0.3750
# 1   2         194                   80.0           0.6250           0.3750
# 2   3         227                   40.0           0.8125           0.1875
# 3   4         167                   30.0           0.7500           0.0000
# 4   5         194                   80.0           0.0000           0.6250
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0            0.000                9.9523                8.5513
# 1            0.000                6.1840                6.1838
# 2            0.000                9.7510                5.6595
# 3            0.250                5.0036                5.0034
# 4            0.375                6.6614                6.6612
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.1775                     90.0026
# 1               23.6287                     90.0186
# 2               13.9630                     90.9688
# 3               13.5318                     89.9888
# 4               24.5813                     89.9960
#
#    lattice_angle_beta_degree  lattice_angle_gamma_degree  \
# 0                    90.0023                     90.0017
# 1                    89.9980                    120.0025
# 2                    91.1228                     30.5185
# 3                    90.0119                    120.0017
# 4                    90.0006                    119.9893
#
#    formation_energy_ev_natom  bandgap_energy_ev
# 0                     0.0680             3.4387
# 1                     0.2490             2.9210
# 2                     0.1821             2.7438
# 3                     0.2172             3.3492
# 4                     0.0505             1.3793

# %% [markdown]
# ### Graph structures

# %%
from torch_geometric.data import Dataset

# %%
import torch
import torch_geometric
from torch.nn import Embedding, Module
from torch_geometric.nn import GCNConv
import networkx as nx
import torch.nn.functional as F

import pandas as pd
from torch.nn import Sequential, Linear, ReLU, GRU
from torch_geometric.nn import NNConv, Set2Set

import pickle
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data

# %%
def construct_pyg_pickle(input_filename, output_filename, is_train_data=True):
    """
    is_train_data: are we generating geometric data for tain or test?
    """
    elem_to_ix = {"Al": 0, "O": 1, "Ga": 2, "In": 3}
    nuclear_charge = {"Al": 13, "O": 8, "Ga": 31, "In": 49}
    list_of_data = []
    with open(input_filename, 'rb') as f:
        train = pickle.load(f)
    for k in train.keys():
        dict_node_element = nx.get_node_attributes(train[k], 'element')
        dict_edge_length = nx.get_edge_attributes(train[k], 'length')
        # copy length attribute from networkx to pyg
        
        assert (list(dict_edge_length.keys()) == list(train[k].edges))  # make sure that length of edge is mapped to the correct edges
        assert (list(dict_node_element.keys()) == list(train[k].nodes))  # make sure that element is mapped to the correct edges

        # for embedding later
        attrx = {}
        for n in dict_node_element:
            attrx[n] = {}
            attrx[n]['element'] = elem_to_ix[dict_node_element[n]]
            attrx[n]['z'] = nuclear_charge[dict_node_element[n]]
        # attrx == {0: {'element': 1}, 6: {'element': 2)}

        nx.set_node_attributes(train[k], attrx)
        pytorch_graph = torch_geometric.utils.from_networkx(train[k])
        # copy length attribute from networkx to pyg
        if is_train_data:
            pytorch_graph.bandgap_energy_ev = train_df[train_df['id'] == k]['bandgap_energy_ev'].values            
            pytorch_graph.formation_energy_ev_natom = train_df[train_df['id'] == k]['formation_energy_ev_natom'].values
        list_of_data.append(pytorch_graph)

    with open(output_filename, 'wb') as f:
        pickle.dump(list_of_data, f)
    return list_of_data

# %%
if not CONVERTED_TO_PYG_DATA:
    train = construct_pyg_pickle("train_struct.pickle", "train_struct_pyg.pickle")
else:
    with open("train_struct_pyg.pickle", 'rb') as f:
        train = pickle.load(f)

# %%
# same as above, for test
if not CONVERTED_TO_PYG_DATA:
    test = construct_pyg_pickle("test_struct.pickle", "test_struct_pyg.pickle", is_train_data=False)
else:
    with open("test_struct_pyg.pickle", 'rb') as f:
        test = pickle.load(f)

# %%
train
# Out:
# {1069: Data(edge_index=[2, 352], element=[80], xyz=[80, 3], z=[80], length=[352], num_nodes=80, bandgap_energy_ev=[1]),
#  1855: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  797: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  2288: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  909: Data(edge_index=[2, 126], element=[38], xyz=[38, 3], z=[38], length=[126], num_nodes=38, bandgap_energy_ev=[1]),
#  135: Data(edge_index=[2, 116], element=[30], xyz=[30, 3], z=[30], length=[116], num_nodes=30, bandgap_energy_ev=[1]),
#  307: Data(edge_index=[2, 376], element=[80], xyz=[80, 3], z=[80], length=[376], num_nodes=80, bandgap_energy_ev=[1]),
#  763: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  551: Data(edge_index=[2, 374], element=[80], xyz=[80, 3], z=[80], length=[374], num_nodes=80, bandgap_energy_ev=[1]),
#  1432: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  1600: Data(edge_index=[2, 270], element=[60], xyz=[60, 3], z=[60], length=[270], num_nodes=60, bandgap_energy_ev=[1]),
#  2085: Data(edge_index=[2, 466], element=[80], xyz=[80, 3], z=[80], length=[466], num_nodes=80, bandgap_energy_ev=[1]),
#  1264: Data(edge_index=[2, 182], element=[40], xyz=[40, 3], z=[40], length=[182], num_nodes=40, bandgap_energy_ev=[1]),
#  61: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  1056: Data(edge_index=[2, 446], element=[80], xyz=[80, 3], z=[80], length=[446], num_nodes=80, bandgap_energy_ev=[1]),
#  1290: Data(edge_index=[2, 316], element=[80], xyz=[80, 3], z=[80], length=[316], num_nodes=80, bandgap_energy_ev=[1]),
#  95: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  2243: Data(edge_index=[2, 406], element=[80], xyz=[80, 3], z=[80], length=[406], num_nodes=80, bandgap_energy_ev=[1]),
#  338: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  936: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  2071: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  556: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  764: Data(edge_index=[2, 194], element=[40], xyz=[40, 3], z=[40], length=[194], num_nodes=40, bandgap_energy_ev=[1]),
#  300: Data(edge_index=[2, 460], element=[80], xyz=[80, 3], z=[80], length=[460], num_nodes=80, bandgap_energy_ev=[1]),
#  2049: Data(edge_index=[2, 334], element=[80], xyz=[80, 3], z=[80], length=[334], num_nodes=80, bandgap_energy_ev=[1]),
#  132: Data(edge_index=[2, 452], element=[80], xyz=[80, 3], z=[80], length=[452], num_nodes=80, bandgap_energy_ev=[1]),
#  1638: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  59: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  1852: Data(edge_index=[2, 182], element=[40], xyz=[40, 3], z=[40], length=[182], num_nodes=40, bandgap_energy_ev=[1]),
#  790: Data(edge_index=[2, 172], element=[40], xyz=[40, 3], z=[40], length=[172], num_nodes=40, bandgap_energy_ev=[1]),
#  931: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  2076: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  2244: Data(edge_index=[2, 176], element=[40], xyz=[40, 3], z=[40], length=[176], num_nodes=40, bandgap_energy_ev=[1]),
#  1899: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  1297: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  569: Data(edge_index=[2, 460], element=[80], xyz=[80, 3], z=[80], length=[460], num_nodes=80, bandgap_energy_ev=[1]),
#  92: Data(edge_index=[2, 126], element=[30], xyz=[30, 3], z=[30], length=[126], num_nodes=30, bandgap_energy_ev=[1]),
#  1051: Data(edge_index=[2, 122], element=[30], xyz=[30, 3], z=[30], length=[122], num_nodes=30, bandgap_energy_ev=[1]),
#  1263: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  66: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  1607: Data(edge_index=[2, 434], element=[80], xyz=[80, 3], z=[80], length=[434], num_nodes=80, bandgap_energy_ev=[1]),
#  2082: Data(edge_index=[2, 164], element=[40], xyz=[40, 3], z=[40], length=[164], num_nodes=40, bandgap_energy_ev=[1]),
#  1435: Data(edge_index=[2, 428], element=[80], xyz=[80, 3], z=[80], length=[428], num_nodes=80, bandgap_energy_ev=[1]),
#  336: Data(edge_index=[2, 316], element=[80], xyz=[80, 3], z=[80], length=[316], num_nodes=80, bandgap_energy_ev=[1]),
#  938: Data(edge_index=[2, 132], element=[38], xyz=[38, 3], z=[38], length=[132], num_nodes=38, bandgap_energy_ev=[1]),
#  104: Data(edge_index=[2, 274], element=[60], xyz=[60, 3], z=[60], length=[274], num_nodes=60, bandgap_energy_ev=[1]),
#  560: Data(edge_index=[2, 184], element=[39], xyz=[39, 3], z=[39], length=[184], num_nodes=39, bandgap_energy_ev=[1]),
#  752: Data(edge_index=[2, 434], element=[80], xyz=[80, 3], z=[80], length=[434], num_nodes=80, bandgap_energy_ev=[1]),
#  1890: Data(edge_index=[2, 142], element=[38], xyz=[38, 3], z=[38], length=[142], num_nodes=38, bandgap_energy_ev=[1]),
#  594: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1058: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  1864: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  1093: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  907: Data(edge_index=[2, 180], element=[40], xyz=[40, 3], z=[40], length=[180], num_nodes=40, bandgap_energy_ev=[1]),
#  2040: Data(edge_index=[2, 118], element=[38], xyz=[38, 3], z=[38], length=[118], num_nodes=38, bandgap_energy_ev=[1]),
#  309: Data(edge_index=[2, 358], element=[80], xyz=[80, 3], z=[80], length=[358], num_nodes=80, bandgap_energy_ev=[1]),
#  2272: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  1631: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  1403: Data(edge_index=[2, 152], element=[38], xyz=[38, 3], z=[38], length=[152], num_nodes=38, bandgap_energy_ev=[1]),
#  2286: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  1067: Data(edge_index=[2, 312], element=[80], xyz=[80, 3], z=[80], length=[312], num_nodes=80, bandgap_energy_ev=[1]),
#  799: Data(edge_index=[2, 406], element=[80], xyz=[80, 3], z=[80], length=[406], num_nodes=80, bandgap_energy_ev=[1]),
#  50: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  1255: Data(edge_index=[2, 172], element=[38], xyz=[38, 3], z=[38], length=[172], num_nodes=38, bandgap_energy_ev=[1]),
#  1609: Data(edge_index=[2, 146], element=[38], xyz=[38, 3], z=[38], length=[146], num_nodes=38, bandgap_energy_ev=[1]),
#  1863: Data(edge_index=[2, 460], element=[80], xyz=[80, 3], z=[80], length=[460], num_nodes=80, bandgap_energy_ev=[1]),
#  68: Data(edge_index=[2, 378], element=[80], xyz=[80, 3], z=[80], length=[378], num_nodes=80, bandgap_energy_ev=[1]),
#  593: Data(edge_index=[2, 338], element=[80], xyz=[80, 3], z=[80], length=[338], num_nodes=80, bandgap_energy_ev=[1]),
#  755: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1897: Data(edge_index=[2, 52], element=[20], xyz=[20, 3], z=[20], length=[52], num_nodes=20, bandgap_energy_ev=[1]),
#  1299: Data(edge_index=[2, 452], element=[80], xyz=[80, 3], z=[80], length=[452], num_nodes=80, bandgap_energy_ev=[1]),
#  567: Data(edge_index=[2, 124], element=[30], xyz=[30, 3], z=[30], length=[124], num_nodes=30, bandgap_energy_ev=[1]),
#  103: Data(edge_index=[2, 426], element=[80], xyz=[80, 3], z=[80], length=[426], num_nodes=80, bandgap_energy_ev=[1]),
#  2078: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  331: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  57: Data(edge_index=[2, 182], element=[40], xyz=[40, 3], z=[40], length=[182], num_nodes=40, bandgap_energy_ev=[1]),
#  1252: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  1060: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  1404: Data(edge_index=[2, 176], element=[40], xyz=[40, 3], z=[40], length=[176], num_nodes=40, bandgap_energy_ev=[1]),
#  2281: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1636: Data(edge_index=[2, 110], element=[38], xyz=[38, 3], z=[38], length=[110], num_nodes=38, bandgap_energy_ev=[1]),
#  2275: Data(edge_index=[2, 424], element=[80], xyz=[80, 3], z=[80], length=[424], num_nodes=80, bandgap_energy_ev=[1]),
#  900: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  2047: Data(edge_index=[2, 450], element=[80], xyz=[80, 3], z=[80], length=[450], num_nodes=80, bandgap_energy_ev=[1]),
#  558: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  1094: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  1808: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  1034: Data(edge_index=[2, 138], element=[38], xyz=[38, 3], z=[38], length=[138], num_nodes=38, bandgap_energy_ev=[1]),
#  1206: Data(edge_index=[2, 266], element=[80], xyz=[80, 3], z=[80], length=[266], num_nodes=80, bandgap_energy_ev=[1]),
#  1662: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  1450: Data(edge_index=[2, 54], element=[20], xyz=[20, 3], z=[20], length=[54], num_nodes=20, bandgap_energy_ev=[1]),
#  1696: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  2013: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  168: Data(edge_index=[2, 120], element=[38], xyz=[38, 3], z=[38], length=[120], num_nodes=38, bandgap_energy_ev=[1]),
#  954: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  2221: Data(edge_index=[2, 422], element=[80], xyz=[80, 3], z=[80], length=[422], num_nodes=80, bandgap_energy_ev=[1]),
#  391: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  1239: Data(edge_index=[2, 182], element=[38], xyz=[38, 3], z=[38], length=[182], num_nodes=38, bandgap_energy_ev=[1]),
#  1837: Data(edge_index=[2, 128], element=[30], xyz=[30, 3], z=[30], length=[128], num_nodes=30, bandgap_energy_ev=[1]),
#  533: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  701: Data(edge_index=[2, 184], element=[40], xyz=[40, 3], z=[40], length=[184], num_nodes=40, bandgap_energy_ev=[1]),
#  365: Data(edge_index=[2, 390], element=[80], xyz=[80, 3], z=[80], length=[390], num_nodes=80, bandgap_energy_ev=[1]),
#  157: Data(edge_index=[2, 378], element=[80], xyz=[80, 3], z=[80], length=[378], num_nodes=80, bandgap_energy_ev=[1]),
#  739: Data(edge_index=[2, 68], element=[20], xyz=[20, 3], z=[20], length=[68], num_nodes=20, bandgap_energy_ev=[1]),
#  2226: Data(edge_index=[2, 326], element=[80], xyz=[80, 3], z=[80], length=[326], num_nodes=80, bandgap_energy_ev=[1]),
#  1691: Data(edge_index=[2, 142], element=[38], xyz=[38, 3], z=[38], length=[142], num_nodes=38, bandgap_energy_ev=[1]),
#  2014: Data(edge_index=[2, 388], element=[80], xyz=[80, 3], z=[80], length=[388], num_nodes=80, bandgap_energy_ev=[1]),
#  953: Data(edge_index=[2, 344], element=[80], xyz=[80, 3], z=[80], length=[344], num_nodes=80, bandgap_energy_ev=[1]),
#  1457: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  1665: Data(edge_index=[2, 164], element=[40], xyz=[40, 3], z=[40], length=[164], num_nodes=40, bandgap_energy_ev=[1]),
#  1201: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  1033: Data(edge_index=[2, 422], element=[80], xyz=[80, 3], z=[80], length=[422], num_nodes=80, bandgap_energy_ev=[1]),
#  150: Data(edge_index=[2, 426], element=[80], xyz=[80, 3], z=[80], length=[426], num_nodes=80, bandgap_energy_ev=[1]),
#  2219: Data(edge_index=[2, 390], element=[80], xyz=[80, 3], z=[80], length=[390], num_nodes=80, bandgap_energy_ev=[1]),
#  362: Data(edge_index=[2, 180], element=[38], xyz=[38, 3], z=[38], length=[180], num_nodes=38, bandgap_energy_ev=[1]),
#  706: Data(edge_index=[2, 374], element=[80], xyz=[80, 3], z=[80], length=[374], num_nodes=80, bandgap_energy_ev=[1]),
#  534: Data(edge_index=[2, 174], element=[39], xyz=[39, 3], z=[39], length=[174], num_nodes=39, bandgap_energy_ev=[1]),
#  1830: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  998: Data(edge_index=[2, 430], element=[80], xyz=[80, 3], z=[80], length=[430], num_nodes=80, bandgap_energy_ev=[1]),
#  1468: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  396: Data(edge_index=[2, 126], element=[38], xyz=[38, 3], z=[38], length=[126], num_nodes=38, bandgap_energy_ev=[1]),
#  1495: Data(edge_index=[2, 400], element=[80], xyz=[80, 3], z=[80], length=[400], num_nodes=80, bandgap_energy_ev=[1]),
#  2210: Data(edge_index=[2, 362], element=[80], xyz=[80, 3], z=[80], length=[362], num_nodes=80, bandgap_energy_ev=[1]),
#  159: Data(edge_index=[2, 156], element=[38], xyz=[38, 3], z=[38], length=[156], num_nodes=38, bandgap_energy_ev=[1]),
#  2022: Data(edge_index=[2, 344], element=[80], xyz=[80, 3], z=[80], length=[344], num_nodes=80, bandgap_energy_ev=[1]),
#  965: Data(edge_index=[2, 300], element=[80], xyz=[80, 3], z=[80], length=[300], num_nodes=80, bandgap_energy_ev=[1]),
#  32: Data(edge_index=[2, 140], element=[38], xyz=[38, 3], z=[38], length=[140], num_nodes=38, bandgap_energy_ev=[1]),
#  1237: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  1839: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  1005: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  1461: Data(edge_index=[2, 194], element=[38], xyz=[38, 3], z=[38], length=[194], num_nodes=38, bandgap_energy_ev=[1]),
#  991: Data(edge_index=[2, 434], element=[80], xyz=[80, 3], z=[80], length=[434], num_nodes=80, bandgap_energy_ev=[1]),
#  1653: Data(edge_index=[2, 314], element=[80], xyz=[80, 3], z=[80], length=[314], num_nodes=80, bandgap_energy_ev=[1]),
#  730: Data(edge_index=[2, 128], element=[38], xyz=[38, 3], z=[38], length=[128], num_nodes=38, bandgap_energy_ev=[1]),
#  502: Data(edge_index=[2, 178], element=[39], xyz=[39, 3], z=[39], length=[178], num_nodes=39, bandgap_energy_ev=[1]),
#  1698: Data(edge_index=[2, 466], element=[80], xyz=[80, 3], z=[80], length=[466], num_nodes=80, bandgap_energy_ev=[1]),
#  166: Data(edge_index=[2, 164], element=[40], xyz=[40, 3], z=[40], length=[164], num_nodes=40, bandgap_energy_ev=[1]),
#  354: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  192: Data(edge_index=[2, 106], element=[38], xyz=[38, 3], z=[38], length=[106], num_nodes=38, bandgap_energy_ev=[1]),
#  1806: Data(edge_index=[2, 118], element=[38], xyz=[38, 3], z=[38], length=[118], num_nodes=38, bandgap_energy_ev=[1]),
#  1208: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  996: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  1654: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  1466: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  398: Data(edge_index=[2, 316], element=[80], xyz=[80, 3], z=[80], length=[316], num_nodes=80, bandgap_energy_ev=[1]),
#  1002: Data(edge_index=[2, 352], element=[80], xyz=[80, 3], z=[80], length=[352], num_nodes=80, bandgap_energy_ev=[1]),
#  35: Data(edge_index=[2, 378], element=[80], xyz=[80, 3], z=[80], length=[378], num_nodes=80, bandgap_energy_ev=[1]),
#  1230: Data(edge_index=[2, 344], element=[80], xyz=[80, 3], z=[80], length=[344], num_nodes=80, bandgap_energy_ev=[1]),
#  708: Data(edge_index=[2, 396], element=[80], xyz=[80, 3], z=[80], length=[396], num_nodes=80, bandgap_energy_ev=[1]),
#  2025: Data(edge_index=[2, 438], element=[80], xyz=[80, 3], z=[80], length=[438], num_nodes=80, bandgap_energy_ev=[1]),
#  962: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  1492: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  2217: Data(edge_index=[2, 116], element=[38], xyz=[38, 3], z=[38], length=[116], num_nodes=38, bandgap_energy_ev=[1]),
#  1801: Data(edge_index=[2, 442], element=[80], xyz=[80, 3], z=[80], length=[442], num_nodes=80, bandgap_energy_ev=[1]),
#  1459: Data(edge_index=[2, 394], element=[80], xyz=[80, 3], z=[80], length=[394], num_nodes=80, bandgap_energy_ev=[1]),
#  195: Data(edge_index=[2, 176], element=[40], xyz=[40, 3], z=[40], length=[176], num_nodes=40, bandgap_energy_ev=[1]),
#  353: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  2228: Data(edge_index=[2, 398], element=[80], xyz=[80, 3], z=[80], length=[398], num_nodes=80, bandgap_energy_ev=[1]),
#  161: Data(edge_index=[2, 336], element=[80], xyz=[80, 3], z=[80], length=[336], num_nodes=80, bandgap_energy_ev=[1]),
#  505: Data(edge_index=[2, 310], element=[80], xyz=[80, 3], z=[80], length=[310], num_nodes=80, bandgap_energy_ev=[1]),
#  737: Data(edge_index=[2, 104], element=[38], xyz=[38, 3], z=[38], length=[104], num_nodes=38, bandgap_energy_ev=[1]),
#  1298: Data(edge_index=[2, 168], element=[39], xyz=[39, 3], z=[39], length=[168], num_nodes=39, bandgap_energy_ev=[1]),
#  566: Data(edge_index=[2, 308], element=[80], xyz=[80, 3], z=[80], length=[308], num_nodes=80, bandgap_energy_ev=[1]),
#  754: Data(edge_index=[2, 362], element=[80], xyz=[80, 3], z=[80], length=[362], num_nodes=80, bandgap_energy_ev=[1]),
#  1896: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  330: Data(edge_index=[2, 358], element=[80], xyz=[80, 3], z=[80], length=[358], num_nodes=80, bandgap_energy_ev=[1]),
#  2079: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  102: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  1608: Data(edge_index=[2, 366], element=[80], xyz=[80, 3], z=[80], length=[366], num_nodes=80, bandgap_energy_ev=[1]),
#  592: Data(edge_index=[2, 390], element=[80], xyz=[80, 3], z=[80], length=[390], num_nodes=80, bandgap_energy_ev=[1]),
#  69: Data(edge_index=[2, 298], element=[80], xyz=[80, 3], z=[80], length=[298], num_nodes=80, bandgap_energy_ev=[1]),
#  1862: Data(edge_index=[2, 140], element=[38], xyz=[38, 3], z=[38], length=[140], num_nodes=38, bandgap_energy_ev=[1]),
#  2046: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  901: Data(edge_index=[2, 120], element=[38], xyz=[38, 3], z=[38], length=[120], num_nodes=38, bandgap_energy_ev=[1]),
#  2274: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  1095: Data(edge_index=[2, 358], element=[80], xyz=[80, 3], z=[80], length=[358], num_nodes=80, bandgap_energy_ev=[1]),
#  559: Data(edge_index=[2, 126], element=[38], xyz=[38, 3], z=[38], length=[126], num_nodes=38, bandgap_energy_ev=[1]),
#  1061: Data(edge_index=[2, 422], element=[80], xyz=[80, 3], z=[80], length=[422], num_nodes=80, bandgap_energy_ev=[1]),
#  56: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  1253: Data(edge_index=[2, 178], element=[40], xyz=[40, 3], z=[40], length=[178], num_nodes=40, bandgap_energy_ev=[1]),
#  1637: Data(edge_index=[2, 186], element=[40], xyz=[40, 3], z=[40], length=[186], num_nodes=40, bandgap_energy_ev=[1]),
#  1405: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  2280: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  1865: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  1059: Data(edge_index=[2, 386], element=[80], xyz=[80, 3], z=[80], length=[386], num_nodes=80, bandgap_energy_ev=[1]),
#  595: Data(edge_index=[2, 180], element=[40], xyz=[40, 3], z=[40], length=[180], num_nodes=40, bandgap_energy_ev=[1]),
#  105: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  939: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  337: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  753: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  1891: Data(edge_index=[2, 384], element=[80], xyz=[80, 3], z=[80], length=[384], num_nodes=80, bandgap_energy_ev=[1]),
#  561: Data(edge_index=[2, 98], element=[30], xyz=[30, 3], z=[30], length=[98], num_nodes=30, bandgap_energy_ev=[1]),
#  1402: Data(edge_index=[2, 176], element=[40], xyz=[40, 3], z=[40], length=[176], num_nodes=40, bandgap_energy_ev=[1]),
#  2287: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  1630: Data(edge_index=[2, 346], element=[80], xyz=[80, 3], z=[80], length=[346], num_nodes=80, bandgap_energy_ev=[1]),
#  51: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  1254: Data(edge_index=[2, 366], element=[80], xyz=[80, 3], z=[80], length=[366], num_nodes=80, bandgap_energy_ev=[1]),
#  1066: Data(edge_index=[2, 98], element=[30], xyz=[30, 3], z=[30], length=[98], num_nodes=30, bandgap_energy_ev=[1]),
#  798: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  1092: Data(edge_index=[2, 424], element=[80], xyz=[80, 3], z=[80], length=[424], num_nodes=80, bandgap_energy_ev=[1]),
#  2273: Data(edge_index=[2, 180], element=[39], xyz=[39, 3], z=[39], length=[180], num_nodes=39, bandgap_energy_ev=[1]),
#  308: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  2041: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  906: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  1639: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1853: Data(edge_index=[2, 432], element=[80], xyz=[80, 3], z=[80], length=[432], num_nodes=80, bandgap_energy_ev=[1]),
#  791: Data(edge_index=[2, 392], element=[80], xyz=[80, 3], z=[80], length=[392], num_nodes=80, bandgap_energy_ev=[1]),
#  58: Data(edge_index=[2, 314], element=[80], xyz=[80, 3], z=[80], length=[314], num_nodes=80, bandgap_energy_ev=[1]),
#  765: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  557: Data(edge_index=[2, 182], element=[40], xyz=[40, 3], z=[40], length=[182], num_nodes=40, bandgap_energy_ev=[1]),
#  133: Data(edge_index=[2, 58], element=[20], xyz=[20, 3], z=[20], length=[58], num_nodes=20, bandgap_energy_ev=[1]),
#  2048: Data(edge_index=[2, 396], element=[80], xyz=[80, 3], z=[80], length=[396], num_nodes=80, bandgap_energy_ev=[1]),
#  301: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  1262: Data(edge_index=[2, 336], element=[80], xyz=[80, 3], z=[80], length=[336], num_nodes=80, bandgap_energy_ev=[1]),
#  67: Data(edge_index=[2, 396], element=[80], xyz=[80, 3], z=[80], length=[396], num_nodes=80, bandgap_energy_ev=[1]),
#  1050: Data(edge_index=[2, 436], element=[80], xyz=[80, 3], z=[80], length=[436], num_nodes=80, bandgap_energy_ev=[1]),
#  1434: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1606: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  2083: Data(edge_index=[2, 366], element=[80], xyz=[80, 3], z=[80], length=[366], num_nodes=80, bandgap_energy_ev=[1]),
#  2245: Data(edge_index=[2, 358], element=[80], xyz=[80, 3], z=[80], length=[358], num_nodes=80, bandgap_energy_ev=[1]),
#  2077: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  930: Data(edge_index=[2, 66], element=[20], xyz=[20, 3], z=[20], length=[66], num_nodes=20, bandgap_energy_ev=[1]),
#  1296: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  93: Data(edge_index=[2, 168], element=[39], xyz=[39, 3], z=[39], length=[168], num_nodes=39, bandgap_energy_ev=[1]),
#  568: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  1898: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  306: Data(edge_index=[2, 292], element=[60], xyz=[60, 3], z=[60], length=[292], num_nodes=60, bandgap_energy_ev=[1]),
#  134: Data(edge_index=[2, 360], element=[80], xyz=[80, 3], z=[80], length=[360], num_nodes=80, bandgap_energy_ev=[1]),
#  908: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  550: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  762: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  1854: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  1068: Data(edge_index=[2, 282], element=[80], xyz=[80, 3], z=[80], length=[282], num_nodes=80, bandgap_energy_ev=[1]),
#  796: Data(edge_index=[2, 174], element=[40], xyz=[40, 3], z=[40], length=[174], num_nodes=40, bandgap_energy_ev=[1]),
#  2289: Data(edge_index=[2, 114], element=[38], xyz=[38, 3], z=[38], length=[114], num_nodes=38, bandgap_energy_ev=[1]),
#  1291: Data(edge_index=[2, 118], element=[30], xyz=[30, 3], z=[30], length=[118], num_nodes=30, bandgap_energy_ev=[1]),
#  94: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  2070: Data(edge_index=[2, 180], element=[40], xyz=[40, 3], z=[40], length=[180], num_nodes=40, bandgap_energy_ev=[1]),
#  937: Data(edge_index=[2, 108], element=[38], xyz=[38, 3], z=[38], length=[108], num_nodes=38, bandgap_energy_ev=[1]),
#  339: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  2242: Data(edge_index=[2, 130], element=[38], xyz=[38, 3], z=[38], length=[130], num_nodes=38, bandgap_energy_ev=[1]),
#  1601: Data(edge_index=[2, 168], element=[40], xyz=[40, 3], z=[40], length=[168], num_nodes=40, bandgap_energy_ev=[1]),
#  2084: Data(edge_index=[2, 392], element=[80], xyz=[80, 3], z=[80], length=[392], num_nodes=80, bandgap_energy_ev=[1]),
#  1433: Data(edge_index=[2, 112], element=[30], xyz=[30, 3], z=[30], length=[112], num_nodes=30, bandgap_energy_ev=[1]),
#  1057: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  1265: Data(edge_index=[2, 176], element=[38], xyz=[38, 3], z=[38], length=[176], num_nodes=38, bandgap_energy_ev=[1]),
#  60: Data(edge_index=[2, 444], element=[80], xyz=[80, 3], z=[80], length=[444], num_nodes=80, bandgap_energy_ev=[1]),
#  709: Data(edge_index=[2, 178], element=[38], xyz=[38, 3], z=[38], length=[178], num_nodes=38, bandgap_energy_ev=[1]),
#  1493: Data(edge_index=[2, 338], element=[80], xyz=[80, 3], z=[80], length=[338], num_nodes=80, bandgap_energy_ev=[1]),
#  2216: Data(edge_index=[2, 162], element=[40], xyz=[40, 3], z=[40], length=[162], num_nodes=40, bandgap_energy_ev=[1]),
#  963: Data(edge_index=[2, 124], element=[38], xyz=[38, 3], z=[38], length=[124], num_nodes=38, bandgap_energy_ev=[1]),
#  2024: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  1467: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  399: Data(edge_index=[2, 158], element=[38], xyz=[38, 3], z=[38], length=[158], num_nodes=38, bandgap_energy_ev=[1]),
#  997: Data(edge_index=[2, 182], element=[40], xyz=[40, 3], z=[40], length=[182], num_nodes=40, bandgap_energy_ev=[1]),
#  1655: Data(edge_index=[2, 462], element=[80], xyz=[80, 3], z=[80], length=[462], num_nodes=80, bandgap_energy_ev=[1]),
#  34: Data(edge_index=[2, 370], element=[80], xyz=[80, 3], z=[80], length=[370], num_nodes=80, bandgap_energy_ev=[1]),
#  1231: Data(edge_index=[2, 128], element=[30], xyz=[30, 3], z=[30], length=[128], num_nodes=30, bandgap_energy_ev=[1]),
#  1003: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  160: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  2229: Data(edge_index=[2, 340], element=[80], xyz=[80, 3], z=[80], length=[340], num_nodes=80, bandgap_energy_ev=[1]),
#  352: Data(edge_index=[2, 456], element=[80], xyz=[80, 3], z=[80], length=[456], num_nodes=80, bandgap_energy_ev=[1]),
#  736: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  504: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  1800: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  194: Data(edge_index=[2, 388], element=[80], xyz=[80, 3], z=[80], length=[388], num_nodes=80, bandgap_energy_ev=[1]),
#  1458: Data(edge_index=[2, 156], element=[40], xyz=[40, 3], z=[40], length=[156], num_nodes=40, bandgap_energy_ev=[1]),
#  1004: Data(edge_index=[2, 118], element=[30], xyz=[30, 3], z=[30], length=[118], num_nodes=30, bandgap_energy_ev=[1]),
#  1838: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  33: Data(edge_index=[2, 178], element=[40], xyz=[40, 3], z=[40], length=[178], num_nodes=40, bandgap_energy_ev=[1]),
#  1236: Data(edge_index=[2, 22], element=[10], xyz=[10, 3], z=[10], length=[22], num_nodes=10, bandgap_energy_ev=[1]),
#  990: Data(edge_index=[2, 68], element=[20], xyz=[20, 3], z=[20], length=[68], num_nodes=20, bandgap_energy_ev=[1]),
#  1652: Data(edge_index=[2, 140], element=[38], xyz=[38, 3], z=[38], length=[140], num_nodes=38, bandgap_energy_ev=[1]),
#  1460: Data(edge_index=[2, 132], element=[38], xyz=[38, 3], z=[38], length=[132], num_nodes=38, bandgap_energy_ev=[1]),
#  964: Data(edge_index=[2, 430], element=[80], xyz=[80, 3], z=[80], length=[430], num_nodes=80, bandgap_energy_ev=[1]),
#  2023: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  158: Data(edge_index=[2, 340], element=[80], xyz=[80, 3], z=[80], length=[340], num_nodes=80, bandgap_energy_ev=[1]),
#  1494: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  2211: Data(edge_index=[2, 372], element=[80], xyz=[80, 3], z=[80], length=[372], num_nodes=80, bandgap_energy_ev=[1]),
#  193: Data(edge_index=[2, 24], element=[10], xyz=[10, 3], z=[10], length=[24], num_nodes=10, bandgap_energy_ev=[1]),
#  1209: Data(edge_index=[2, 404], element=[80], xyz=[80, 3], z=[80], length=[404], num_nodes=80, bandgap_energy_ev=[1]),
#  1807: Data(edge_index=[2, 426], element=[80], xyz=[80, 3], z=[80], length=[426], num_nodes=80, bandgap_energy_ev=[1]),
#  503: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  731: Data(edge_index=[2, 360], element=[80], xyz=[80, 3], z=[80], length=[360], num_nodes=80, bandgap_energy_ev=[1]),
#  355: Data(edge_index=[2, 122], element=[30], xyz=[30, 3], z=[30], length=[122], num_nodes=30, bandgap_energy_ev=[1]),
#  1699: Data(edge_index=[2, 122], element=[30], xyz=[30, 3], z=[30], length=[122], num_nodes=30, bandgap_energy_ev=[1]),
#  167: Data(edge_index=[2, 300], element=[80], xyz=[80, 3], z=[80], length=[300], num_nodes=80, bandgap_energy_ev=[1]),
#  1664: Data(edge_index=[2, 462], element=[80], xyz=[80, 3], z=[80], length=[462], num_nodes=80, bandgap_energy_ev=[1]),
#  1456: Data(edge_index=[2, 124], element=[38], xyz=[38, 3], z=[38], length=[124], num_nodes=38, bandgap_energy_ev=[1]),
#  1032: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  1200: Data(edge_index=[2, 170], element=[40], xyz=[40, 3], z=[40], length=[170], num_nodes=40, bandgap_energy_ev=[1]),
#  738: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  1690: Data(edge_index=[2, 114], element=[38], xyz=[38, 3], z=[38], length=[114], num_nodes=38, bandgap_energy_ev=[1]),
#  952: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  2015: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  2227: Data(edge_index=[2, 134], element=[40], xyz=[40, 3], z=[40], length=[134], num_nodes=40, bandgap_energy_ev=[1]),
#  1831: Data(edge_index=[2, 18], element=[10], xyz=[10, 3], z=[10], length=[18], num_nodes=10, bandgap_energy_ev=[1]),
#  1469: Data(edge_index=[2, 122], element=[30], xyz=[30, 3], z=[30], length=[122], num_nodes=30, bandgap_energy_ev=[1]),
#  397: Data(edge_index=[2, 434], element=[80], xyz=[80, 3], z=[80], length=[434], num_nodes=80, bandgap_energy_ev=[1]),
#  999: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  363: Data(edge_index=[2, 116], element=[38], xyz=[38, 3], z=[38], length=[116], num_nodes=38, bandgap_energy_ev=[1]),
#  2218: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  151: Data(edge_index=[2, 70], element=[20], xyz=[20, 3], z=[20], length=[70], num_nodes=20, bandgap_energy_ev=[1]),
#  535: Data(edge_index=[2, 430], element=[80], xyz=[80, 3], z=[80], length=[430], num_nodes=80, bandgap_energy_ev=[1]),
#  707: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  2220: Data(edge_index=[2, 392], element=[80], xyz=[80, 3], z=[80], length=[392], num_nodes=80, bandgap_energy_ev=[1]),
#  1697: Data(edge_index=[2, 130], element=[40], xyz=[40, 3], z=[40], length=[130], num_nodes=40, bandgap_energy_ev=[1]),
#  955: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  169: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  2012: Data(edge_index=[2, 324], element=[80], xyz=[80, 3], z=[80], length=[324], num_nodes=80, bandgap_energy_ev=[1]),
#  1207: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  1035: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  1809: Data(edge_index=[2, 54], element=[20], xyz=[20, 3], z=[20], length=[54], num_nodes=20, bandgap_energy_ev=[1]),
#  1451: Data(edge_index=[2, 156], element=[40], xyz=[40, 3], z=[40], length=[156], num_nodes=40, bandgap_energy_ev=[1]),
#  1663: Data(edge_index=[2, 108], element=[38], xyz=[38, 3], z=[38], length=[108], num_nodes=38, bandgap_energy_ev=[1]),
#  700: Data(edge_index=[2, 468], element=[80], xyz=[80, 3], z=[80], length=[468], num_nodes=80, bandgap_energy_ev=[1]),
#  532: Data(edge_index=[2, 118], element=[30], xyz=[30, 3], z=[30], length=[118], num_nodes=30, bandgap_energy_ev=[1]),
#  156: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  364: Data(edge_index=[2, 132], element=[40], xyz=[40, 3], z=[40], length=[132], num_nodes=40, bandgap_energy_ev=[1]),
#  390: Data(edge_index=[2, 136], element=[38], xyz=[38, 3], z=[38], length=[136], num_nodes=38, bandgap_energy_ev=[1]),
#  1836: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  1238: Data(edge_index=[2, 424], element=[80], xyz=[80, 3], z=[80], length=[424], num_nodes=80, bandgap_energy_ev=[1]),
#  1944: Data(edge_index=[2, 48], element=[20], xyz=[20, 3], z=[20], length=[48], num_nodes=20, bandgap_energy_ev=[1]),
#  1178: Data(edge_index=[2, 332], element=[80], xyz=[80, 3], z=[80], length=[332], num_nodes=80, bandgap_energy_ev=[1]),
#  686: Data(edge_index=[2, 62], element=[20], xyz=[20, 3], z=[20], length=[62], num_nodes=20, bandgap_energy_ev=[1]),
#  2399: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  818: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  216: Data(edge_index=[2, 428], element=[80], xyz=[80, 3], z=[80], length=[428], num_nodes=80, bandgap_energy_ev=[1]),
#  672: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  440: Data(edge_index=[2, 124], element=[38], xyz=[38, 3], z=[38], length=[124], num_nodes=38, bandgap_energy_ev=[1]),
#  1523: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  1711: Data(edge_index=[2, 112], element=[38], xyz=[38, 3], z=[38], length=[112], num_nodes=38, bandgap_energy_ev=[1]),
#  2194: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  1375: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  1147: Data(edge_index=[2, 404], element=[80], xyz=[80, 3], z=[80], length=[404], num_nodes=80, bandgap_energy_ev=[1]),
#  1381: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  229: Data(edge_index=[2, 138], element=[40], xyz=[40, 3], z=[40], length=[138], num_nodes=40, bandgap_energy_ev=[1]),
#  2352: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  2160: Data(edge_index=[2, 118], element=[30], xyz=[30, 3], z=[30], length=[118], num_nodes=30, bandgap_energy_ev=[1]),
#  827: Data(edge_index=[2, 366], element=[80], xyz=[80, 3], z=[80], length=[366], num_nodes=80, bandgap_energy_ev=[1]),
#  447: Data(edge_index=[2, 302], element=[80], xyz=[80, 3], z=[80], length=[302], num_nodes=80, bandgap_energy_ev=[1]),
#  675: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  211: Data(edge_index=[2, 370], element=[80], xyz=[80, 3], z=[80], length=[370], num_nodes=80, bandgap_energy_ev=[1]),
#  2158: Data(edge_index=[2, 128], element=[30], xyz=[30, 3], z=[30], length=[128], num_nodes=30, bandgap_energy_ev=[1]),
#  1729: Data(edge_index=[2, 250], element=[60], xyz=[60, 3], z=[60], length=[250], num_nodes=60, bandgap_energy_ev=[1]),
#  1943: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  681: Data(edge_index=[2, 116], element=[30], xyz=[30, 3], z=[30], length=[116], num_nodes=30, bandgap_energy_ev=[1]),
#  2167: Data(edge_index=[2, 444], element=[80], xyz=[80, 3], z=[80], length=[444], num_nodes=80, bandgap_energy_ev=[1]),
#  820: Data(edge_index=[2, 112], element=[30], xyz=[30, 3], z=[30], length=[112], num_nodes=30, bandgap_energy_ev=[1]),
#  2355: Data(edge_index=[2, 438], element=[80], xyz=[80, 3], z=[80], length=[438], num_nodes=80, bandgap_energy_ev=[1]),
#  1988: Data(edge_index=[2, 234], element=[60], xyz=[60, 3], z=[60], length=[234], num_nodes=60, bandgap_energy_ev=[1]),
#  1386: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  478: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  1140: Data(edge_index=[2, 166], element=[39], xyz=[39, 3], z=[39], length=[166], num_nodes=39, bandgap_energy_ev=[1]),
#  1372: Data(edge_index=[2, 64], element=[20], xyz=[20, 3], z=[20], length=[64], num_nodes=20, bandgap_energy_ev=[1]),
#  1716: Data(edge_index=[2, 180], element=[40], xyz=[40, 3], z=[40], length=[180], num_nodes=40, bandgap_energy_ev=[1]),
#  2193: Data(edge_index=[2, 370], element=[80], xyz=[80, 3], z=[80], length=[370], num_nodes=80, bandgap_energy_ev=[1]),
#  1524: Data(edge_index=[2, 178], element=[40], xyz=[40, 3], z=[40], length=[178], num_nodes=40, bandgap_energy_ev=[1]),
#  227: Data(edge_index=[2, 112], element=[30], xyz=[30, 3], z=[30], length=[112], num_nodes=30, bandgap_energy_ev=[1]),
#  829: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  471: Data(edge_index=[2, 338], element=[80], xyz=[80, 3], z=[80], length=[338], num_nodes=80, bandgap_energy_ev=[1]),
#  643: Data(edge_index=[2, 376], element=[80], xyz=[80, 3], z=[80], length=[376], num_nodes=80, bandgap_energy_ev=[1]),
#  1981: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  485: Data(edge_index=[2, 446], element=[80], xyz=[80, 3], z=[80], length=[446], num_nodes=80, bandgap_energy_ev=[1]),
#  1975: Data(edge_index=[2, 398], element=[80], xyz=[80, 3], z=[80], length=[398], num_nodes=80, bandgap_energy_ev=[1]),
#  1149: Data(edge_index=[2, 116], element=[30], xyz=[30, 3], z=[30], length=[116], num_nodes=30, bandgap_energy_ev=[1]),
#  1182: Data(edge_index=[2, 262], element=[60], xyz=[60, 3], z=[60], length=[262], num_nodes=60, bandgap_energy_ev=[1]),
#  2151: Data(edge_index=[2, 414], element=[80], xyz=[80, 3], z=[80], length=[414], num_nodes=80, bandgap_energy_ev=[1]),
#  816: Data(edge_index=[2, 400], element=[80], xyz=[80, 3], z=[80], length=[400], num_nodes=80, bandgap_energy_ev=[1]),
#  2363: Data(edge_index=[2, 344], element=[80], xyz=[80, 3], z=[80], length=[344], num_nodes=80, bandgap_energy_ev=[1]),
#  218: Data(edge_index=[2, 320], element=[80], xyz=[80, 3], z=[80], length=[320], num_nodes=80, bandgap_energy_ev=[1]),
#  1720: Data(edge_index=[2, 194], element=[40], xyz=[40, 3], z=[40], length=[194], num_nodes=40, bandgap_energy_ev=[1]),
#  1512: Data(edge_index=[2, 392], element=[80], xyz=[80, 3], z=[80], length=[392], num_nodes=80, bandgap_energy_ev=[1]),
#  2397: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  1176: Data(edge_index=[2, 346], element=[80], xyz=[80, 3], z=[80], length=[346], num_nodes=80, bandgap_energy_ev=[1]),
#  688: Data(edge_index=[2, 388], element=[80], xyz=[80, 3], z=[80], length=[388], num_nodes=80, bandgap_energy_ev=[1]),
#  1344: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  1718: Data(edge_index=[2, 132], element=[38], xyz=[38, 3], z=[38], length=[132], num_nodes=38, bandgap_energy_ev=[1]),
#  1972: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  482: Data(edge_index=[2, 390], element=[80], xyz=[80, 3], z=[80], length=[390], num_nodes=80, bandgap_energy_ev=[1]),
#  644: Data(edge_index=[2, 314], element=[80], xyz=[80, 3], z=[80], length=[314], num_nodes=80, bandgap_energy_ev=[1]),
#  1986: Data(edge_index=[2, 398], element=[80], xyz=[80, 3], z=[80], length=[398], num_nodes=80, bandgap_energy_ev=[1]),
#  1388: Data(edge_index=[2, 120], element=[30], xyz=[30, 3], z=[30], length=[120], num_nodes=30, bandgap_energy_ev=[1]),
#  476: Data(edge_index=[2, 406], element=[80], xyz=[80, 3], z=[80], length=[406], num_nodes=80, bandgap_energy_ev=[1]),
#  2169: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  220: Data(edge_index=[2, 378], element=[80], xyz=[80, 3], z=[80], length=[378], num_nodes=80, bandgap_energy_ev=[1]),
#  1343: Data(edge_index=[2, 126], element=[38], xyz=[38, 3], z=[38], length=[126], num_nodes=38, bandgap_energy_ev=[1]),
#  1171: Data(edge_index=[2, 378], element=[80], xyz=[80, 3], z=[80], length=[378], num_nodes=80, bandgap_energy_ev=[1]),
#  1515: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  2390: Data(edge_index=[2, 172], element=[40], xyz=[40, 3], z=[40], length=[172], num_nodes=40, bandgap_energy_ev=[1]),
#  1727: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  2364: Data(edge_index=[2, 138], element=[38], xyz=[38, 3], z=[38], length=[138], num_nodes=38, bandgap_energy_ev=[1]),
#  2156: Data(edge_index=[2, 170], element=[40], xyz=[40, 3], z=[40], length=[170], num_nodes=40, bandgap_energy_ev=[1]),
#  811: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  449: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  1185: Data(edge_index=[2, 462], element=[80], xyz=[80, 3], z=[80], length=[462], num_nodes=80, bandgap_energy_ev=[1]),
#  1125: Data(edge_index=[2, 346], element=[80], xyz=[80, 3], z=[80], length=[346], num_nodes=80, bandgap_energy_ev=[1]),
#  1919: Data(edge_index=[2, 398], element=[80], xyz=[80, 3], z=[80], length=[398], num_nodes=80, bandgap_energy_ev=[1]),
#  1317: Data(edge_index=[2, 360], element=[80], xyz=[80, 3], z=[80], length=[360], num_nodes=80, bandgap_energy_ev=[1]),
#  1773: Data(edge_index=[2, 178], element=[40], xyz=[40, 3], z=[40], length=[178], num_nodes=40, bandgap_energy_ev=[1]),
#  1541: Data(edge_index=[2, 180], element=[40], xyz=[40, 3], z=[40], length=[180], num_nodes=40, bandgap_energy_ev=[1]),
# ...
#  1966: Data(edge_index=[2, 352], element=[80], xyz=[80, 3], z=[80], length=[352], num_nodes=80, bandgap_energy_ev=[1]),
#  462: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  1992: Data(edge_index=[2, 174], element=[40], xyz=[40, 3], z=[40], length=[174], num_nodes=40, bandgap_energy_ev=[1]),
#  650: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  234: Data(edge_index=[2, 406], element=[80], xyz=[80, 3], z=[80], length=[406], num_nodes=80, bandgap_energy_ev=[1]),
#  346: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  948: Data(edge_index=[2, 422], element=[80], xyz=[80, 3], z=[80], length=[422], num_nodes=80, bandgap_energy_ev=[1]),
#  174: Data(edge_index=[2, 368], element=[80], xyz=[80, 3], z=[80], length=[368], num_nodes=80, bandgap_energy_ev=[1]),
#  510: Data(edge_index=[2, 426], element=[80], xyz=[80, 3], z=[80], length=[426], num_nodes=80, bandgap_energy_ev=[1]),
#  722: Data(edge_index=[2, 138], element=[38], xyz=[38, 3], z=[38], length=[138], num_nodes=38, bandgap_energy_ev=[1]),
#  1028: Data(edge_index=[2, 112], element=[30], xyz=[30, 3], z=[30], length=[112], num_nodes=30, bandgap_energy_ev=[1]),
#  1814: Data(edge_index=[2, 64], element=[20], xyz=[20, 3], z=[20], length=[64], num_nodes=20, bandgap_energy_ev=[1]),
#  180: Data(edge_index=[2, 132], element=[30], xyz=[30, 3], z=[30], length=[132], num_nodes=30, bandgap_energy_ev=[1]),
#  977: Data(edge_index=[2, 126], element=[30], xyz=[30, 3], z=[30], length=[126], num_nodes=30, bandgap_energy_ev=[1]),
#  2030: Data(edge_index=[2, 128], element=[30], xyz=[30, 3], z=[30], length=[128], num_nodes=30, bandgap_energy_ev=[1]),
#  379: Data(edge_index=[2, 322], element=[80], xyz=[80, 3], z=[80], length=[322], num_nodes=80, bandgap_energy_ev=[1]),
#  2202: Data(edge_index=[2, 166], element=[39], xyz=[39, 3], z=[39], length=[166], num_nodes=39, bandgap_energy_ev=[1]),
#  1487: Data(edge_index=[2, 168], element=[40], xyz=[40, 3], z=[40], length=[168], num_nodes=40, bandgap_energy_ev=[1]),
#  1641: Data(edge_index=[2, 120], element=[30], xyz=[30, 3], z=[30], length=[120], num_nodes=30, bandgap_energy_ev=[1]),
#  983: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  1473: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  1017: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  1225: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  20: Data(edge_index=[2, 62], element=[20], xyz=[20, 3], z=[20], length=[62], num_nodes=20, bandgap_energy_ev=[1]),
#  187: Data(edge_index=[2, 98], element=[30], xyz=[30, 3], z=[30], length=[98], num_nodes=30, bandgap_energy_ev=[1]),
#  1679: Data(edge_index=[2, 446], element=[80], xyz=[80, 3], z=[80], length=[446], num_nodes=80, bandgap_energy_ev=[1]),
#  1813: Data(edge_index=[2, 336], element=[80], xyz=[80, 3], z=[80], length=[336], num_nodes=80, bandgap_energy_ev=[1]),
#  18: Data(edge_index=[2, 352], element=[80], xyz=[80, 3], z=[80], length=[352], num_nodes=80, bandgap_energy_ev=[1]),
#  725: Data(edge_index=[2, 190], element=[40], xyz=[40, 3], z=[40], length=[190], num_nodes=40, bandgap_energy_ev=[1]),
#  517: Data(edge_index=[2, 140], element=[38], xyz=[38, 3], z=[38], length=[140], num_nodes=38, bandgap_energy_ev=[1]),
#  173: Data(edge_index=[2, 152], element=[38], xyz=[38, 3], z=[38], length=[152], num_nodes=38, bandgap_energy_ev=[1]),
#  2008: Data(edge_index=[2, 440], element=[80], xyz=[80, 3], z=[80], length=[440], num_nodes=80, bandgap_energy_ev=[1]),
#  341: Data(edge_index=[2, 396], element=[80], xyz=[80, 3], z=[80], length=[396], num_nodes=80, bandgap_energy_ev=[1]),
#  1222: Data(edge_index=[2, 456], element=[80], xyz=[80, 3], z=[80], length=[456], num_nodes=80, bandgap_energy_ev=[1]),
#  27: Data(edge_index=[2, 174], element=[39], xyz=[39, 3], z=[39], length=[174], num_nodes=39, bandgap_energy_ev=[1]),
#  1010: Data(edge_index=[2, 396], element=[80], xyz=[80, 3], z=[80], length=[396], num_nodes=80, bandgap_energy_ev=[1]),
#  1474: Data(edge_index=[2, 440], element=[80], xyz=[80, 3], z=[80], length=[440], num_nodes=80, bandgap_energy_ev=[1]),
#  1646: Data(edge_index=[2, 346], element=[80], xyz=[80, 3], z=[80], length=[346], num_nodes=80, bandgap_energy_ev=[1]),
#  9: Data(edge_index=[2, 436], element=[80], xyz=[80, 3], z=[80], length=[436], num_nodes=80, bandgap_energy_ev=[1]),
#  984: Data(edge_index=[2, 376], element=[80], xyz=[80, 3], z=[80], length=[376], num_nodes=80, bandgap_energy_ev=[1]),
#  2205: Data(edge_index=[2, 342], element=[80], xyz=[80, 3], z=[80], length=[342], num_nodes=80, bandgap_energy_ev=[1]),
#  1480: Data(edge_index=[2, 420], element=[80], xyz=[80, 3], z=[80], length=[420], num_nodes=80, bandgap_energy_ev=[1]),
#  970: Data(edge_index=[2, 142], element=[38], xyz=[38, 3], z=[38], length=[142], num_nodes=38, bandgap_energy_ev=[1]),
#  2037: Data(edge_index=[2, 278], element=[60], xyz=[60, 3], z=[60], length=[278], num_nodes=60, bandgap_energy_ev=[1]),
#  528: Data(edge_index=[2, 106], element=[30], xyz=[30, 3], z=[30], length=[106], num_nodes=30, bandgap_energy_ev=[1]),
#  1019: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  1825: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  383: Data(edge_index=[2, 392], element=[80], xyz=[80, 3], z=[80], length=[392], num_nodes=80, bandgap_energy_ev=[1]),
#  979: Data(edge_index=[2, 322], element=[80], xyz=[80, 3], z=[80], length=[322], num_nodes=80, bandgap_energy_ev=[1]),
#  145: Data(edge_index=[2, 394], element=[80], xyz=[80, 3], z=[80], length=[394], num_nodes=80, bandgap_energy_ev=[1]),
#  377: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  1489: Data(edge_index=[2, 406], element=[80], xyz=[80, 3], z=[80], length=[406], num_nodes=80, bandgap_energy_ev=[1]),
#  713: Data(edge_index=[2, 338], element=[80], xyz=[80, 3], z=[80], length=[338], num_nodes=80, bandgap_energy_ev=[1]),
#  521: Data(edge_index=[2, 368], element=[80], xyz=[80, 3], z=[80], length=[368], num_nodes=80, bandgap_energy_ev=[1]),
#  1442: Data(edge_index=[2, 394], element=[80], xyz=[80, 3], z=[80], length=[394], num_nodes=80, bandgap_energy_ev=[1]),
#  1670: Data(edge_index=[2, 128], element=[38], xyz=[38, 3], z=[38], length=[128], num_nodes=38, bandgap_energy_ev=[1]),
#  11: Data(edge_index=[2, 242], element=[60], xyz=[60, 3], z=[60], length=[242], num_nodes=60, bandgap_energy_ev=[1]),
#  1214: Data(edge_index=[2, 466], element=[80], xyz=[80, 3], z=[80], length=[466], num_nodes=80, bandgap_energy_ev=[1]),
#  1026: Data(edge_index=[2, 460], element=[80], xyz=[80, 3], z=[80], length=[460], num_nodes=80, bandgap_energy_ev=[1]),
#  2233: Data(edge_index=[2, 266], element=[60], xyz=[60, 3], z=[60], length=[266], num_nodes=60, bandgap_energy_ev=[1]),
#  348: Data(edge_index=[2, 346], element=[80], xyz=[80, 3], z=[80], length=[346], num_nodes=80, bandgap_energy_ev=[1]),
#  946: Data(edge_index=[2, 426], element=[80], xyz=[80, 3], z=[80], length=[426], num_nodes=80, bandgap_energy_ev=[1]),
#  2001: Data(edge_index=[2, 386], element=[80], xyz=[80, 3], z=[80], length=[386], num_nodes=80, bandgap_energy_ev=[1]),
#  1684: Data(edge_index=[2, 140], element=[38], xyz=[38, 3], z=[38], length=[140], num_nodes=38, bandgap_energy_ev=[1]),
#  526: Data(edge_index=[2, 258], element=[60], xyz=[60, 3], z=[60], length=[258], num_nodes=60, bandgap_energy_ev=[1]),
#  714: Data(edge_index=[2, 170], element=[39], xyz=[39, 3], z=[39], length=[170], num_nodes=39, bandgap_energy_ev=[1]),
#  370: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  2039: Data(edge_index=[2, 108], element=[30], xyz=[30, 3], z=[30], length=[108], num_nodes=30, bandgap_energy_ev=[1]),
#  142: Data(edge_index=[2, 122], element=[30], xyz=[30, 3], z=[30], length=[122], num_nodes=30, bandgap_energy_ev=[1]),
#  384: Data(edge_index=[2, 394], element=[80], xyz=[80, 3], z=[80], length=[394], num_nodes=80, bandgap_energy_ev=[1]),
#  7: Data(edge_index=[2, 460], element=[80], xyz=[80, 3], z=[80], length=[460], num_nodes=80, bandgap_energy_ev=[1]),
#  1648: Data(edge_index=[2, 328], element=[80], xyz=[80, 3], z=[80], length=[328], num_nodes=80, bandgap_energy_ev=[1]),
#  29: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  1822: Data(edge_index=[2, 110], element=[30], xyz=[30, 3], z=[30], length=[110], num_nodes=30, bandgap_energy_ev=[1]),
#  941: Data(edge_index=[2, 348], element=[80], xyz=[80, 3], z=[80], length=[348], num_nodes=80, bandgap_energy_ev=[1]),
#  2006: Data(edge_index=[2, 350], element=[80], xyz=[80, 3], z=[80], length=[350], num_nodes=80, bandgap_energy_ev=[1]),
#  1683: Data(edge_index=[2, 388], element=[80], xyz=[80, 3], z=[80], length=[388], num_nodes=80, bandgap_energy_ev=[1]),
#  2234: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  519: Data(edge_index=[2, 404], element=[80], xyz=[80, 3], z=[80], length=[404], num_nodes=80, bandgap_energy_ev=[1]),
#  1021: Data(edge_index=[2, 422], element=[80], xyz=[80, 3], z=[80], length=[422], num_nodes=80, bandgap_energy_ev=[1]),
#  16: Data(edge_index=[2, 380], element=[80], xyz=[80, 3], z=[80], length=[380], num_nodes=80, bandgap_energy_ev=[1]),
#  1213: Data(edge_index=[2, 176], element=[40], xyz=[40, 3], z=[40], length=[176], num_nodes=40, bandgap_energy_ev=[1]),
#  189: Data(edge_index=[2, 370], element=[80], xyz=[80, 3], z=[80], length=[370], num_nodes=80, bandgap_energy_ev=[1]),
#  1677: Data(edge_index=[2, 296], element=[80], xyz=[80, 3], z=[80], length=[296], num_nodes=80, bandgap_energy_ev=[1]),
#  1445: Data(edge_index=[2, 130], element=[38], xyz=[38, 3], z=[38], length=[130], num_nodes=38, bandgap_energy_ev=[1]),
#  2260: Data(edge_index=[2, 324], element=[80], xyz=[80, 3], z=[80], length=[324], num_nodes=80, bandgap_energy_ev=[1]),
#  129: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  2052: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  915: Data(edge_index=[2, 326], element=[80], xyz=[80, 3], z=[80], length=[326], num_nodes=80, bandgap_energy_ev=[1]),
#  1081: Data(edge_index=[2, 116], element=[30], xyz=[30, 3], z=[30], length=[116], num_nodes=30, bandgap_energy_ev=[1]),
#  1247: Data(edge_index=[2, 120], element=[30], xyz=[30, 3], z=[30], length=[120], num_nodes=30, bandgap_energy_ev=[1]),
#  42: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  1849: Data(edge_index=[2, 354], element=[80], xyz=[80, 3], z=[80], length=[354], num_nodes=80, bandgap_energy_ev=[1]),
#  1075: Data(edge_index=[2, 450], element=[80], xyz=[80, 3], z=[80], length=[450], num_nodes=80, bandgap_energy_ev=[1]),
#  2294: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  1411: Data(edge_index=[2, 356], element=[80], xyz=[80, 3], z=[80], length=[356], num_nodes=80, bandgap_energy_ev=[1]),
#  1623: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  1882: Data(edge_index=[2, 370], element=[80], xyz=[80, 3], z=[80], length=[370], num_nodes=80, bandgap_energy_ev=[1]),
#  740: Data(edge_index=[2, 304], element=[80], xyz=[80, 3], z=[80], length=[304], num_nodes=80, bandgap_energy_ev=[1]),
#  89: Data(edge_index=[2, 114], element=[38], xyz=[38, 3], z=[38], length=[114], num_nodes=38, bandgap_energy_ev=[1]),
#  572: Data(edge_index=[2, 114], element=[30], xyz=[30, 3], z=[30], length=[114], num_nodes=30, bandgap_energy_ev=[1]),
#  116: Data(edge_index=[2, 324], element=[80], xyz=[80, 3], z=[80], length=[324], num_nodes=80, bandgap_energy_ev=[1]),
#  324: Data(edge_index=[2, 408], element=[80], xyz=[80, 3], z=[80], length=[408], num_nodes=80, bandgap_energy_ev=[1]),
#  2099: Data(edge_index=[2, 344], element=[80], xyz=[80, 3], z=[80], length=[344], num_nodes=80, bandgap_energy_ev=[1]),
#  1876: Data(edge_index=[2, 160], element=[39], xyz=[39, 3], z=[39], length=[160], num_nodes=39, bandgap_energy_ev=[1]),
#  586: Data(edge_index=[2, 466], element=[80], xyz=[80, 3], z=[80], length=[466], num_nodes=80, bandgap_energy_ev=[1]),
#  1278: Data(edge_index=[2, 418], element=[80], xyz=[80, 3], z=[80], length=[418], num_nodes=80, bandgap_energy_ev=[1]),
#  1624: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  2293: Data(edge_index=[2, 334], element=[80], xyz=[80, 3], z=[80], length=[334], num_nodes=80, bandgap_energy_ev=[1]),
#  1416: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  1072: Data(edge_index=[2, 382], element=[80], xyz=[80, 3], z=[80], length=[382], num_nodes=80, bandgap_energy_ev=[1]),
#  1240: Data(edge_index=[2, 364], element=[80], xyz=[80, 3], z=[80], length=[364], num_nodes=80, bandgap_energy_ev=[1]),
#  45: Data(edge_index=[2, 430], element=[80], xyz=[80, 3], z=[80], length=[430], num_nodes=80, bandgap_energy_ev=[1]),
#  778: Data(edge_index=[2, 362], element=[80], xyz=[80, 3], z=[80], length=[362], num_nodes=80, bandgap_energy_ev=[1]),
#  1086: Data(edge_index=[2, 464], element=[80], xyz=[80, 3], z=[80], length=[464], num_nodes=80, bandgap_energy_ev=[1]),
#  2055: Data(edge_index=[2, 128], element=[38], xyz=[38, 3], z=[38], length=[128], num_nodes=38, bandgap_energy_ev=[1]),
#  912: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  2267: Data(edge_index=[2, 366], element=[80], xyz=[80, 3], z=[80], length=[366], num_nodes=80, bandgap_energy_ev=[1]),
#  581: Data(edge_index=[2, 412], element=[80], xyz=[80, 3], z=[80], length=[412], num_nodes=80, bandgap_energy_ev=[1]),
#  1871: Data(edge_index=[2, 402], element=[80], xyz=[80, 3], z=[80], length=[402], num_nodes=80, bandgap_energy_ev=[1]),
#  1429: Data(edge_index=[2, 102], element=[30], xyz=[30, 3], z=[30], length=[102], num_nodes=30, bandgap_energy_ev=[1]),
#  323: Data(edge_index=[2, 400], element=[80], xyz=[80, 3], z=[80], length=[400], num_nodes=80, bandgap_energy_ev=[1]),
#  2258: Data(edge_index=[2, 416], element=[80], xyz=[80, 3], z=[80], length=[416], num_nodes=80, bandgap_energy_ev=[1]),
#  111: Data(edge_index=[2, 374], element=[80], xyz=[80, 3], z=[80], length=[374], num_nodes=80, bandgap_energy_ev=[1]),
#  575: Data(edge_index=[2, 358], element=[80], xyz=[80, 3], z=[80], length=[358], num_nodes=80, bandgap_energy_ev=[1]),
#  1885: Data(edge_index=[2, 456], element=[80], xyz=[80, 3], z=[80], length=[456], num_nodes=80, bandgap_energy_ev=[1]),
#  747: Data(edge_index=[2, 174], element=[40], xyz=[40, 3], z=[40], length=[174], num_nodes=40, bandgap_energy_ev=[1]),
#  1878: Data(edge_index=[2, 454], element=[80], xyz=[80, 3], z=[80], length=[454], num_nodes=80, bandgap_energy_ev=[1]),
#  1044: Data(edge_index=[2, 318], element=[80], xyz=[80, 3], z=[80], length=[318], num_nodes=80, bandgap_energy_ev=[1]),
#  588: Data(edge_index=[2, 164], element=[39], xyz=[39, 3], z=[39], length=[164], num_nodes=39, bandgap_energy_ev=[1]),
#  73: Data(edge_index=[2, 394], element=[80], xyz=[80, 3], z=[80], length=[394], num_nodes=80, bandgap_energy_ev=[1]),
#  1276: Data(edge_index=[2, 60], element=[20], xyz=[20, 3], z=[20], length=[60], num_nodes=20, bandgap_energy_ev=[1]),
#  2097: Data(edge_index=[2, 100], element=[30], xyz=[30, 3], z=[30], length=[100], num_nodes=30, bandgap_energy_ev=[1]),
#  ...}

# %%
EMBED_DIM = 3
DIM = 32

# %%
class NomadGCN(torch.nn.Module):
    
    def __init__(self):
        super().__init__()
        self.elem_to_ix = {"Al": 0, "O": 1, "Ga": 2, "In": 3}
        self.embed = Embedding(len(self.elem_to_ix), EMBED_DIM)
        self.lin0 = torch.nn.Linear(EMBED_DIM, DIM)

        # nn = Sequential(Linear(5, 128), ReLU(), Linear(128, DIM * DIM))   # previous
        nn = Sequential(Linear(1, 128), ReLU(), Linear(128, DIM * DIM))
        self.conv = NNConv(DIM, DIM, nn, aggr='mean')
        self.gru = GRU(DIM, DIM)
        self.set2set = Set2Set(DIM, processing_steps=3)
        self.lin1 = torch.nn.Linear(2 * DIM, DIM)
        self.lin2 = torch.nn.Linear(DIM, 1)
    
    def forward(self, data):
        import pdb; pdb.set_trace()
        data.x = torch.tensor([self.elem_to_ix[w] for w in data.nodes])
        out = F.relu(self.lin0(self.embed(data.x)))
        h = out.unsqueeze(0)
        for i in range(3):
            m = F.relu(self.conv(out, data.edge_index, data.length))  # data.length is data.edge_attr
            out, h = self.gru(m.unsqueeze(0), h)
            out = out.squeeze(0)
        out = self.set2set(out, data.batch)
        out = F.relu(self.lin1(out))
        out = self.lin2(out)
        return out.view(-1)

# %%
def train_nn():
    for i in range(EPOCH):
        for data in nomad_loader:
            ouput = net(data)
            loss = mse(output, label)

# %%
class NomadDataset(Dataset):
    
    def __init__(self, data: dict):
        super().__init__(None, None, None, None)
        self.data = data
        self.data_indices = list(self.data.keys())
        
    def len(self):
        return len(self.data)

    def get(self, idx: int):
        return self.data[self.data_indices[idx]]

# %%
# dataset = NomadDataset()
nomad_loader = DataLoader(list(train.values()), shuffle=True)            
net = NomadGCN()
train_nn()
# Out:
# /Users/minh.chau/miniconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/data/storage.py:266: UserWarning: Unable to accurately infer 'num_nodes' from the attribute set '{'x', 'xyz', 'edge_attr', 'bandgap_energy_ev', 'edge_index'}'. Please explicitly set 'num_nodes' as an attribute of 'data' to suppress this warning
#   " to suppress this warning")
# > <ipython-input-52-b982f9ad56f6>(19)forward()
#      17     def forward(self, data):
#      18         import pdb; pdb.set_trace()
# ---> 19         data.x = torch.tensor([self.elem_to_ix[w] for w in data.nodes])
#      20         out = F.relu(self.lin0(self.embed(data.x)))
#      21         h = out.unsqueeze(0)
# ipdb>  c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/data/storage.py in __getattr__(self, key)
#      49         try:
# ---> 50             return self[key]
#      51         except KeyError:
#
# ~/miniconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/data/storage.py in __getitem__(self, key)
#      69     def __getitem__(self, key: str) -> Any:
# ---> 70         return self._mapping[key]
#      71
#
# KeyError: 'nodes'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5879fd701068> in <module>
#       2 nomad_loader = DataLoader(list(train.values()), shuffle=True)
#       3 net = NomadGCN()
# ----> 4 train_nn()
#
# <ipython-input-53-f21269216622> in train_nn()
#       2     for i in range(EPOCH):
#       3         for data in nomad_loader:
# ----> 4             ouput = net(data)
#       5             loss = mse(output, label)
#
# ~/miniconda3/envs/chem/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-52-b982f9ad56f6> in forward(self, data)
#      17     def forward(self, data):
#      18         import pdb; pdb.set_trace()
# ---> 19         data.x = torch.tensor([self.elem_to_ix[w] for w in data.nodes])
#      20         out = F.relu(self.lin0(self.embed(data.x)))
#      21         h = out.unsqueeze(0)
#
# ~/miniconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/data/data.py in __getattr__(self, key)
#     360                 "dataset, remove the 'processed/' directory in the dataset's "
#     361                 "root folder and try again.")
# --> 362         return getattr(self._store, key)
#     363
#     364     def __setattr__(self, key: str, value: Any):
#
# ~/miniconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/data/storage.py in __getattr__(self, key)
#      51         except KeyError:
#      52             raise AttributeError(
# ---> 53                 f"'{self.__class__.__name__}' object has no attribute '{key}'")
#      54
#      55     def __setattr__(self, key: str, value: Any):
#
# AttributeError: 'GlobalStorage' object has no attribute 'nodes'
